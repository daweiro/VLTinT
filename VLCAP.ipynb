# %% [markdown]
# <a href="https://colab.research.google.com/github/daweiro/VLTinT/blob/main/VLCAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/UARK-AICV/VLCAP.git
# !cd VLCAP
# Out:
# Cloning into 'VLCAP'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 163 (delta 24), reused 48 (delta 14), pack-reused 99
# Receiving objects: 100% (163/163), 94.32 MiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# Updating files: 100% (80/80), done.

# %%
# !source setup.sh
# Out:
# /bin/bash: setup.sh: No such file or directory

# %%
# %%bash
# mkdir -p VLCAP/data/anet
# #cd data/anet
# #unzip anet_c3d
# #unzip anet_clip_b16

# %% [markdown]
# TRAINING

# %%
#TRAINNING
# %%bash 
scripts/train.sh anet true

# %% [markdown]
# EVAULATION
# 1. Generate captions

# %%
# %%bash
# scripts/translate_greedy.sh anet_re_* [val/test]

# %% [markdown]
# Replace anet_re_* with your own model directory name. The generated captions are saved at results/anet_re_*/greedy_pred_val.json

# %% [markdown]
# 2. Evaluate generated captions

# %%
# %%bash
# scripts/eval.sh anet [val/test] results/anet_re_*/greedy_pred_[val/test].json

# %% [markdown]
# The results should be comparable with the results we present at Table 5 of the paper.
#
# https://arxiv.org/pdf/2206.12972v1.pdf#page=1
#
#
# Table 5. Ablation study on the contribution of the proposed VL feature and VL loss LV L on ActivityNet Captions dataset.
# ![Screenshot 2023-04-19 at 18.22.47.png](data:image/png;base64,...)
